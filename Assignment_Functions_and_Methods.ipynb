# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyam092006/ml_new/blob/main/Assignment_Functions_and_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u> Problem 1</u>
#
# ### Write a function which takes the excel column name as an input and returns the corresponding column number. A few examples are :
#
# * column name = <code>'J'</code> , column number = <code>10</code>
# * column name = <code>'AP'</code> , column number = <code>42</code>
# * column name = <code>'AAA'</code>, column number = <code>703</code>

# %%
def get_excel_column_number(column_name):

    alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    mapping = dict(zip(alphabets, range(1, 27)))


    column_number = 0
    power = 0

    for ch in reversed(column_name):
        column_number += mapping[ch] * (26 ** power)
        power += 1

    return column_number



print(get_excel_column_number("J"))    # 10
print(get_excel_column_number("AP"))   # 42
print(get_excel_column_number("AAA"))  # 703
# Out:
# 10
# 42
# 703

# %%
# Check

# %%
# Check

# %% [markdown]
# # <u> Problem 2 </u>
#
# ### Write a Python function which takes a sentence and a length value as inputs and returns the counts of those words from the sentence whose length is equal to the provided input length value.
#
# ### Suppose if the input for the length value is 5, it will return the count of all those words which are of length 5

# %%
marvel_quote = "The world has changed and none of us can go back. All we can do is our best, and sometimes the best that we can do is to start over."

# %%
import string

def fix(sentence, length=5):
    cnt = 0
    sen = sentence.split()

    for word in sen:
        word = word.strip(string.punctuation)
        if len(word) == length:
            cnt += 1

    return cnt

l = "The world has changed and none of us can go back. All we can do is our best, and sometimes the best that we can do is to start over."
print(fix(l))
# Out:
# 2

# %%
# Check on the sample sentenc
