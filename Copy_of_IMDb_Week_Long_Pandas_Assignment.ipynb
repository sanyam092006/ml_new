# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyam092006/ml_new/blob/main/Copy_of_IMDb_Week_Long_Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # IMDb Dataset - Assignment
#
# Complete all questions during the week. Write your solutions below each question.

# %% [markdown]
# ### Question 1
# Load the IMDb dataset using Pandas.

# %%
# Write your solution here
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 2
# Display the first 10 rows of the dataset.

# %%
# Write your solution here
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)
print(df.head(10))
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# ...

# %% [markdown]
# ### Question 3
# Display the last 10 rows of the dataset.

# %%
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)
print(df.tail(10))
# Out:
#         id                              belongs_to_collection    budget  \
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2991  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# ...

# %% [markdown]
# ### Question 4
# Find the total number of rows and columns in the dataset.

# %%
# Write your solution here
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)
print(df.shape)
# Out:
# (3000, 23)

# %% [markdown]
# ### Question 5
# Display all column names.

# %%
# Write your solution here
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)
print(df.columns)
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# ### Question 6
# Check the data types of all columns.

# %%
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# ### Question 7
# Find the total number of missing values in each column.

# %%
# Write your solution here
print(df.isnull().sum())
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %% [markdown]
# ### Question 8
# Generate summary statistics using describe().

# %%
# Write your solution here
print(df.describe())
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %% [markdown]
# ### Question 1
# Display rows 10 to 20 and columns 2 to 5 using iloc.

# %%
# Write your solution here
print(df.iloc[10:21,2:6])
# Out:
#        budget                                             genres  \
# 10    1000000                      [{'id': 18, 'name': 'Drama'}]
# 11          0                     [{'id': 35, 'name': 'Comedy'}]
# 12   15000000                      [{'id': 18, 'name': 'Drama'}]
# 13   53000000  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 14  102000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15     500000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 16   26000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 17          0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 18    8000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 19   32000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20   80000000  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
#
#                                  homepage    imdb_id
# 10                                    NaN  tt0075148
# 11                                    NaN  tt0093857
# ...

# %% [markdown]
# ### Question 2
# Display the first 15 rows using iloc.

# %%
# Write your solution here
print(df.iloc[:15,:])
# Out:
#     id                              belongs_to_collection     budget  \
# 0    1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...   14000000
# 1    2  [{'id': 107674, 'name': 'The Princess Diaries ...   40000000
# 2    3                                                NaN    3300000
# 3    4                                                NaN    1200000
# 4    5                                                NaN          0
# 5    6                                                NaN    8000000
# 6    7                                                NaN   14000000
# 7    8                                                NaN          0
# 8    9  [{'id': 256377, 'name': 'The Muppet Collection...          0
# 9   10                                                NaN    6000000
# 10  11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...    1000000
# 11  12  [{'id': 48190, 'name': 'Revenge of the Nerds C...          0
# 12  13                                                NaN   15000000
# ...

# %% [markdown]
# ### Question 3
# Extract only the columns: title, budget, revenue using loc.

# %%
# Write your solution here
print(df.loc[:,['original_title','budget','revenue']])
# Out:
#                                 original_title    budget    revenue
# 0                       Hot Tub Time Machine 2  14000000   12314651
# 1     The Princess Diaries 2: Royal Engagement  40000000   95149435
# 2                                     Whiplash   3300000   13092000
# 3                                      Kahaani   1200000   16000000
# 4                                         마린보이         0    3923970
# ...                                        ...       ...        ...
# 2995                                   Chasers         0    1596687
# 2996                               Vi är bäst!         0     180590
# 2997                   The Long Kiss Goodnight  65000000   89456761
# 2998                          Along Came Polly  42000000  171963386
# 2999                                 Abduction  35000000   82087155
#
# [3000 rows x 3 columns]

# %% [markdown]
# ### Question 4
# Display only the title and runtime columns.

# %%
# Write your solution here
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
fil="/content/drive/MyDrive/imdb_data.csv"
df=pd.read_csv(fil)

print(df.loc[:,['original_title','runtime']])
# Out:
#                                 original_title  runtime
# 0                       Hot Tub Time Machine 2     93.0
# 1     The Princess Diaries 2: Royal Engagement    113.0
# 2                                     Whiplash    105.0
# 3                                      Kahaani    122.0
# 4                                         마린보이    118.0
# ...                                        ...      ...
# 2995                                   Chasers    102.0
# 2996                               Vi är bäst!    102.0
# 2997                   The Long Kiss Goodnight    120.0
# 2998                          Along Came Polly     90.0
# 2999                                 Abduction    106.0
#
# [3000 rows x 2 columns]

# %% [markdown]
# ### Question 5
# Extract the last 20 rows of the dataset.

# %%
# Write your solution here
print(df.tail(20))
# Out:
#         id                              belongs_to_collection    budget  \
# 2980  2981                                                NaN    300000
# 2981  2982                                                NaN         0
# 2982  2983                                                NaN    500000
# 2983  2984                                                NaN  35000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2986  2987                                                NaN  20000000
# 2987  2988                                                NaN         0
# 2988  2989                                                NaN         0
# 2989  2990                                                NaN         0
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# ...

# %% [markdown]
# ### Question 6
# Display rows 50 to 100 with only title and popularity columns.

# %%
# Write your solution here
print(df.loc[50:101,['original_title','popularity']])
# Out:
#                                        original_title  popularity
# 50                               Aanrijding in Moscou    1.572904
# 51                                     The Great Race    4.473327
# 52                      The Last Flight of Noah's Ark    1.012665
# 53                                          For Keeps    5.410839
# 54                                              Risen    8.759801
# 55                                         Son in Law    9.122718
# 56                                            Joueuse    2.947980
# 57                                     Batman & Robin   17.038824
# 58                                Were The World Mine    1.882446
# 59                            All About the Benjamins    3.909079
# 60                                      Casino Royale   23.065078
# 61                                            Trapeze    1.801071
# 62                                             Fallen    6.381612
# ...

# %% [markdown]
# ### Question 1
# Find all movies whose original language is English (en).

# %%
# Write your solution here
print(df[df['original_language']=='en'])
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 2
# Find all movies whose original language is Hindi (hi).

# %%
# Write your solution here
print(df[df['original_language']=='hi'])
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 213    214                                                NaN   6700000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# ...

# %% [markdown]
# ### Question 3
# Display only the title and original_language columns for Hindi movies.

# %%
# Write your solution here
print(df[df['original_language']=='hi'][['title','original_language']])
# Out:
#                                  title original_language
# 3                              Kahaani                hi
# 213                      Rowdy Rathore                hi
# 371                          Thank You                hi
# 401         The Legend of Bhagat Singh                hi
# 419   Dear Guest, When Will You Leave?                hi
# 481             Chandni Chowk To China                hi
# 585                             Dangal                hi
# 627                                Fan                hi
# 671                    Anjaana Anjaani                hi
# 695                          Tere Naam                hi
# 771                            Kaminey                hi
# 840                             Neerja                hi
# 848                         Raanjhanaa                hi
# 970                          Heropanti                hi
# 1004                      The Lunchbox                hi
# ...

# %% [markdown]
# ### Question 4
# Find movies having a budget greater than 100 million.

# %%
# Write your solution here
print(df[df['budget']>100000000])
# Out:
#         id                              belongs_to_collection     budget  \
# 14      15                                                NaN  102000000
# 34      35  [{'id': 90863, 'name': 'Rush Hour Collection',...  140000000
# 57      58  [{'id': 120794, 'name': 'Batman Collection', '...  125000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 121    122  [{'id': 106768, 'name': 'Tarzan (Animation) Co...  150000000
# ...    ...                                                ...        ...
# 2866  2867  [{'id': 52984, 'name': 'National Treasure Coll...  130000000
# 2880  2881                                                NaN  150000000
# 2899  2900                                                NaN  127500000
# 2927  2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 2938  2939  [{'id': 135416, 'name': 'Prometheus Collection...  130000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 5
# Find movies with revenue greater than 500 million.

# %%
# Write your solution here
df[df['revenue']>500000000]
# Out:
#         id                              belongs_to_collection     budget  \
# 46      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 114    115  [{'id': 119, 'name': 'The Lord of the Rings Co...   93000000
# 188    189                                                NaN  180000000
# 203    204                                                NaN   75000000
# ...    ...                                                ...        ...
# 2647  2648  [{'id': 87359, 'name': 'Mission: Impossible Co...  145000000
# 2737  2738  [{'id': 645, 'name': 'James Bond Collection', ...  245000000
# 2739  2740  [{'id': 468222, 'name': 'The Incredibles Colle...   92000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 2802  2803  [{'id': 1241, 'name': 'Harry Potter Collection...  100000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 6
# Find movies whose runtime is greater than 150 minutes.

# %%
# Write your solution here
print(df[df['runtime']>150])
# Out:
#         id belongs_to_collection    budget  \
# 47      48                   NaN  44000000
# 51      52                   NaN  12000000
# 76      77                   NaN    500000
# 97      98                   NaN         0
# 107    108                   NaN  72000000
# ...    ...                   ...       ...
# 2860  2861                   NaN  22000000
# 2877  2878                   NaN  18000000
# 2932  2933                   NaN  12000000
# 2944  2945                   NaN  31500000
# 2965  2966                   NaN  61000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# ...

# %% [markdown]
# ### Question 7
# Find movies with popularity greater than the average popularity.

# %%
# Write your solution here
print(df[df['popularity']>df['popularity'].mean()])
# Out:
#         id                              belongs_to_collection    budget  \
# 2        3                                                NaN   3300000
# 10      11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...         0
# 12      13                                                NaN  15000000
# 13      14  [{'id': 91698, 'name': 'Chili Palmer Collectio...  53000000
# ...    ...                                                ...       ...
# 2993  2994                                                NaN  60000000
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 8
# Find all movies having a vote_average greater than 8.

# %%
# Write your solution here

# %% [markdown]
# ### Question 1
# Create a new column called half_runtime.

# %%
# Write your solution here
df['half_runtime']=df['runtime']/2
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 2
# Create a new column called double_runtime.

# %%
# Write your solution here
df['double_runtime']=df['runtime']*2
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 3
# Create a new column called profit = revenue - budget.

# %%
# Write your solution here
df['profit']=df['revenue']-df['budget']
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 4
# Create a new column called profit_percentage.

# %%
# Write your solution here
df["profit_percentage"]=(df['profit']/df['budget'])*100
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 5
# Create a column named budget_in_crores.

# %%
# Write your solution here
df['budget_in_crores']=df['budget']/10000000

# %% [markdown]
# ### Question 6
# Create a column named runtime_hours.

# %%
# Write your solution here
df['runtime_hours']=df['runtime']/60
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 1
# Find the maximum profit.

# %%
# Write your solution here
print(df['profit'].max())
# Out:
# 1316249360

# %% [markdown]
# ### Question 2
# Find the minimum profit.

# %%
# Write your solution here
print(df['profit'].min())
# Out:
# -107447384

# %% [markdown]
# ### Question 3
# Find the average profit.

# %%
# Write your solution here
print(df['profit'].mean())
# Out:
# 44194517.77866667

# %% [markdown]
# ### Question 4
# Find the median profit.

# %%
# Write your solution here
print(df['profit'].median())
# Out:
# 6121122.5

# %% [markdown]
# ### Question 5
# Find the mode of profit.

# %%
# Write your solution here
print(df['profit'].mode())
# Out:
# 0    0
# Name: profit, dtype: int64

# %% [markdown]
# ### Question 6
# Find the total profit generated by all movies.

# %%
# Write your solution here
print(df['profit'].sum())
# Out:
# 132583553336

# %% [markdown]
# ### Question 7
# Find the maximum runtime.

# %%
# Write your solution here
print(df['runtime'].max())
# Out:
# 338.0

# %% [markdown]
# ### Question 8
# Find the minimum runtime.

# %%
# Write your solution here
print(df['runtime'].min())
# Out:
# 0.0

# %% [markdown]
# ### Question 9
# Find the average runtime.

# %%
print(df['runtime'].mean())
# Out:
# 107.85657104736491

# %% [markdown]
# ### Question 10
# Find the movie having the highest revenue.

# %%
# Write your solution here
df[df['revenue']==df['revenue'].max()]
# Out:
#         id                              belongs_to_collection     budget  \
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
#
#                                                  genres  \
# 1126  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                homepage    imdb_id original_language  \
# 1126  http://marvel.com/avengers_movie/  tt0848228                en
#
#      original_title                                           overview  \
# 1126   The Avengers  When an unexpected enemy emerges and threatens...
#
#       popularity  ...                                           Keywords  \
# 1126   89.887648  ...  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
#
#                                                    cast  \
# 1126  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
#
#                                                    crew     revenue  \
# 1126  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
#
# ...

# %% [markdown]
# ### Question 11
# Find the movie having the lowest budget.

# %%
# Write your solution here
df[df['budget']==df['budget'].min()]
# Out:
#         id                              belongs_to_collection  budget  \
# 4        5                                                NaN       0
# 7        8                                                NaN       0
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...       0
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...       0
# 17      18                                                NaN       0
# ...    ...                                                ...     ...
# 2989  2990                                                NaN       0
# 2990  2991                                                NaN       0
# 2994  2995                                                NaN       0
# 2995  2996                                                NaN       0
# 2996  2997                                                NaN       0
#
#                                                  genres homepage    imdb_id  \
# ...

# %% [markdown]
# ### Question 1
# List the top 10 movies by revenue.

# %%
# Write your solution here
df.sort_values(by = 'revenue',ascending = False)[['title','revenue']].head(10)
# Out:
#                                             title     revenue
# 1126                                 The Avengers  1519557910
# 1761                                    Furious 7  1506249360
# 2770                      Avengers: Age of Ultron  1405403694
# 684                          Beauty and the Beast  1262886337
# 2322               Transformers: Dark of the Moon  1123746996
# 906                         The Dark Knight Rises  1084939099
# 2135  Pirates of the Caribbean: On Stranger Tides  1045713802
# 2562                                 Finding Dory  1028570889
# 881                           Alice in Wonderland  1025491110
# 734                                      Zootopia  1023784195

# %% [markdown]
# ### Question 2
# List the top 10 movies by profit.

# %%
# Write your solution here
df.sort_values(by = 'profit',ascending = False)[['title','profit']].head(10)
# Out:
#                                       title      profit
# 1761                              Furious 7  1316249360
# 1126                           The Avengers  1299557910
# 2770                Avengers: Age of Ultron  1125403694
# 684                    Beauty and the Beast  1102886337
# 2322         Transformers: Dark of the Moon   928746996
# 734                                Zootopia   873784195
# 1735                          Jurassic Park   857100000
# 543   The Lord of the Rings: The Two Towers   847287400
# 906                   The Dark Knight Rises   834939099
# 2562                           Finding Dory   828570889

# %% [markdown]
# ### Question 3
# List the top 10 movies by popularity.

# %%
# Write your solution here
df.sort_values(by = 'popularity',ascending = False)[['title','popularity']].head(10)
# Out:
#                                title  popularity
# 518                     Wonder Woman  294.337037
# 684             Beauty and the Beast  287.253654
# 1695                     Baby Driver  228.032744
# 2326                        Deadpool  187.860492
# 2126  Guardians of the Galaxy Vol. 2  185.330992
# 1309                       Gone Girl  154.801009
# 1715  War for the Planet of the Apes  146.161786
# 1673                 The Dark Knight  123.167259
# 1126                    The Avengers   89.887648
# 2293                      The Circle   88.439243

# %% [markdown]
# ### Question 4
# Find the 10 longest movies.

# %%
# Write your solution here
df.sort_values(by='runtime',ascending=False).head(10)
# Out:
#         id belongs_to_collection    budget  \
# 1211  1212                   NaN  18000000
# 1922  1923                   NaN  31115000
# 523    524                   NaN  13000000
# 1302  1303                   NaN  44000000
# 1914  1915                   NaN  56000000
# 2353  2354                   NaN   8376800
# 625    626                   NaN  15000000
# 1975  1976                   NaN   2000000
# 1731  1732                   NaN   3900000
# 2120  2121                   NaN  12000000
#
#                                                  genres  \
# 1211  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1922  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 523   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 1302  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 1914  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 2353  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 625   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...

# %% [markdown]
# ### Question 5
# Find the 10 shortest movies.

# %%
# Write your solution here
df.sort_values(by='runtime',ascending=False).tail(10)
# Out:
#         id                              belongs_to_collection   budget  \
# 2865  2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...  5579750
# 1255  1256                                                NaN        0
# 1541  1542                                                NaN   750000
# 390    391                                                NaN  6843500
# 2645  2646                                                NaN        0
# 2498  2499  [{'id': 106790, 'name': 'Hooked Collection', '...  3500000
# 591    592                                                NaN        0
# 1874  1875                                                NaN        0
# 1335  1336                                                NaN  6000000
# 2302  2303                                                NaN        0
#
#                                                  genres  \
# 2865                     [{'id': 35, 'name': 'Comedy'}]
# 1255                    [{'id': 37, 'name': 'Western'}]
# ...

# %% [markdown]
# ### Question 6
# Find the total number of movies available in each language.

# %%
# Write your solution here
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# ko      20
# cn      20
# zh      19
# de      18
# ta      16
# sv       8
# pt       6
# nl       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# te       2
# pl       2
# fi       2
# ml       2
# sr       1
# cs       1
# mr       1
# ar       1
# he       1
# ur       1
# el       1
# vi       1
# nb       1
# bn       1
# id       1
# Name: count, dtype: int64

# %% [markdown]
# ### Question 7
# Find the language with the highest number of movies.

# %%
# Write your solution here
df['original_language'].value_counts().sort_values(ascending=False).head(1)
# Out:
# original_language
# en    2575
# Name: count, dtype: int64

# %% [markdown]
# ### Question 8
# Find the average runtime for each language.

# %%
df['average_runtime'] = df['runtime'].mean()

unique_languages_df = df[['original_language', 'average_runtime']].drop_duplicates(subset='original_language')
unique_languages_df
# Out:
#      original_language  average_runtime
# 0                   en       107.856571
# 3                   hi       107.856571
# 4                   ko       107.856571
# 15                  sr       107.856571
# 30                  fr       107.856571
# 45                  it       107.856571
# 50                  nl       107.856571
# 67                  zh       107.856571
# 71                  es       107.856571
# 73                  cs       107.856571
# 76                  ta       107.856571
# 87                  cn       107.856571
# 95                  ru       107.856571
# 104                 tr       107.856571
# 183                 ja       107.856571
# 195                 fa       107.856571
# 218                 sv       107.856571
# 247                 de       107.856571
# 276                 te       107.856571
# 293                 pt       107.856571
# 586                 mr       107.856571
# 661                 da       107.856571
# ...

# %% [markdown]
# ### Question 9
# Find the average profit for each language.

# %%
# Write your solution here
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 1
# Find the movie with the highest profit percentage.

# %%
# Write your solution here
df.sort_values(by='profit_percentage',ascending=False)[['original_title','profit_percentage']].head(1)
# Out:
#      original_title  profit_percentage
# 2996    Vi är bäst!                inf

# %% [markdown]
# ### Question 2
# Find movies that earned more than 5 times their budget.

# %%
# Write your solution here
df[df['profit']==5*df['budget']][['original_title','budget','revenue','profit']]
# Out:
#      original_title  budget  revenue   profit
# 2270   Mean Streets  500000  3000000  2500000

# %% [markdown]
# ### Question 3
# Find movies that resulted in a loss.

# %%
# Write your solution here
df[df['profit']<0][['original_title','budget','revenue','profit']]
# Out:
#                               original_title    budget   revenue    profit
# 0                     Hot Tub Time Machine 2  14000000  12314651  -1685349
# 5     Pinocchio and the Emperor of the Night   8000000   3261638  -4738362
# 15                                   Šišanje    500000       198   -499802
# 18                               Chalet Girl   8000000   1749457  -6250543
# 27                                   What If  11000000   7847000  -3153000
# ...                                      ...       ...       ...       ...
# 2977                              Angel Eyes  53000000  29700000 -23300000
# 2982                                 Smashed    500000    376597   -123403
# 2983                           Anna Karenina  35000000    791830 -34208170
# 2985                             Freedomland  37665000  14655628 -23009372
# 2986                               Paparazzi  20000000  16605763  -3394237
#
# [655 rows x 4 columns]

# %% [markdown]
# ### Question 4
# Calculate the percentage of profitable movies.

# %%
# Write your solution here
print((df['profit']>0).mean()*100)
# Out:
# 77.9

# %% [markdown]
# ### Question 5
# Calculate the percentage of loss-making movies.

# %%
# Write your solution here
print((df['profit']<0).mean()*100)
# Out:
# 21.833333333333332

# %% [markdown]
# ### Question 6
# Find the top 5 most profitable Hindi movies.

# %%
# Write your solution here
df[df['original_language']=='hi'].sort_values(by='profit',ascending=False).head(5)
# Out:
#         id                              belongs_to_collection    budget  \
# 585    586                                                NaN  10400000
# 2239  2240  [{'id': 44976, 'name': 'Dhoom Series', 'poster...  19500000
# 1572  1573                                                NaN   9100000
# 1656  1657                                                NaN  18000000
# 1732  1733  [{'id': 419784, 'name': 'Masti Collection', 'p...   5500000
#
#                                                  genres  \
# 585                       [{'id': 18, 'name': 'Drama'}]
# 2239  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 1572  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 1656  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 1732  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                                homepage    imdb_id  \
# 585                                                 NaN  tt5074352
# ...

# %% [markdown]
# ### Question 7
# Find the top 5 most profitable English movies.

# %%
# Write your solution here
# Write your solution here
df[df['original_language']=='en'].sort_values(by='profit',ascending=False).head(5)
# Out:
#         id                              belongs_to_collection     budget  \
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 684    685                                                NaN  160000000
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
#
#                                                  genres  \
# 1761                     [{'id': 28, 'name': 'Action'}]
# 1126  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2770  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 684   [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 2322  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                                                homepage    imdb_id  \
# 1761                           http://www.furious7.com/  tt2820852
# ...

# %% [markdown]
# ### Question 8
# Find all movies with runtime between 120 and 180 minutes.

# %%
# Write your solution here
df[(df['runtime']>120) & (df['runtime']<180)]
# Out:
#         id                              belongs_to_collection     budget  \
# 3        4                                                NaN    1200000
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# ...    ...                                                ...        ...
# 2969  2970                                                NaN   19800000
# 2970  2971                                                NaN   25000000
# 2980  2981                                                NaN     300000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
#
#                                                  genres  \
# ...

# %% [markdown]
# ### Question 9
# Find movies with revenue greater than 1 billion.

# %%
df[df['revenue']>1000000000]
# Write your solution here
# Out:
#         id                              belongs_to_collection     budget  \
# 684    685                                                NaN  160000000
# 734    735                                                NaN  150000000
# 881    882  [{'id': 261307, 'name': 'Alice in Wonderland C...  200000000
# 906    907  [{'id': 263, 'name': 'The Dark Knight Collecti...  250000000
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1673  1674  [{'id': 263, 'name': 'The Dark Knight Collecti...  185000000
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 2532  2533  [{'id': 121938, 'name': 'The Hobbit Collection...  250000000
# 2562  2563  [{'id': 137697, 'name': 'Finding Nemo Collecti...  200000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
#
# ...

# %% [markdown]
# ### Question 10
# Create a report showing Total Movies, Average Budget, Average Revenue, Average Profit, Maximum Profit, Minimum Profit.

# %%
# Write your solution here
df1 = df.groupby('original_language')['runtime'].mean()
df1
# Out:
# original_language
# ar     98.000000
# bn    125.000000
# cn    105.450000
# cs     90.000000
# da    105.400000
# de    122.294118
# el     91.000000
# en    106.984078
# es    100.372093
# fa     96.400000
# fi    100.000000
# fr    106.294872
# he     90.000000
# hi    148.880952
# hu    126.000000
# id    150.000000
# it     91.625000
# ja    112.972973
# ko    115.100000
# ml    137.000000
# mr    162.000000
# nb    103.000000
# nl    107.333333
# no     95.500000
# pl     99.000000
# pt    114.666667
# ro    108.750000
# ru     95.586957
# sr     97.000000
# sv    122.375000
# ta    159.875000
# te    146.000000
# tr    119.000000
# ur     94.000000
# vi    135.000000
# zh    121.368421
# Name: runtime, dtype: float64

# %% [markdown]
# ### Question 11
# Create a final summary dashboard using Pandas.

# %%
# Write your solution here
df1 = df.groupby('original_language')['profit'].mean()
df1
# Out:
# original_language
# ar    1.347747e+06
# bn    5.363640e+05
# cn    2.289881e+07
# cs    1.739300e+04
# da    8.557093e+06
# de    1.641414e+07
# el    7.849000e+06
# en    4.931629e+07
# es    6.874230e+06
# fa    6.761852e+05
# fi   -5.263340e+05
# fr    9.643460e+06
# he    9.125849e+06
# hi    1.863042e+07
# hu   -6.085407e+05
# id   -1.872791e+06
# it    1.286771e+07
# ja    2.344045e+07
# ko    9.347554e+06
# ml    1.105000e+06
# mr    2.900000e+06
# nb    6.596780e+05
# nl    1.066334e+06
# no    6.110675e+05
# pl    1.133119e+07
# pt   -1.714683e+06
# ro   -4.903502e+05
# ru    3.869827e+06
# sr   -4.998020e+05
# sv    1.075551e+07
# ta    9.987754e+06
# te    6.642485e+06
# tr    5.149674e+07
# ur    5.019860e+05
# vi   -6.610000e+05
# zh    5.096795e+07
# Name: profit, dtype: float64
