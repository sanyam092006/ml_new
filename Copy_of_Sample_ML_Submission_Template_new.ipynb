# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyam092006/ml_new/blob/main/Copy_of_Sample_ML_Submission_Template_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# To develop a machine learning model that accurately predicts the heating load of residential buildings based on their architectural characteristics, and to compare the performance of Linear Regression, Ridge, Lasso, RidgeCV, LassoCV, ElasticNet, and ElasticNetCV in terms of prediction accuracy and generalization.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('/content/drive/MyDrive/ENB2012_data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (768, 10)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# %%
# Dataset Describe

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.isnull().sum()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
import matplotlib.pyplot as plt

# Numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(15,10))

for i, col in enumerate(num_cols, 1):
    plt.subplot(4, 3, i)
    plt.boxplot(df[col], vert=False)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
df.rename(columns={
    'X1': 'Relative Compactness',
    'X2': 'Surface Area',
    'X3': 'Wall Area',
    'X4': 'Roof Area',
    'X5': 'Overall Height',
    'X6': 'Orientation',
    'X7': 'Glazing Area',
    'X8': 'Glazing Area Distribution',
    'Y1': 'Heating Load',
    'Y2': 'Cooling Load'
}, inplace=True)

int_cols = df.select_dtypes(include='int').columns

df[int_cols] = df[int_cols].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative Compactness       768 non-null    float64
#  1   Surface Area               768 non-null    float64
#  2   Wall Area                  768 non-null    float64
#  3   Roof Area                  768 non-null    float64
#  4   Overall Height             768 non-null    float64
#  5   Orientation                768 non-null    float64
#  6   Glazing Area               768 non-null    float64
#  7   Glazing Area Distribution  768 non-null    float64
#  8   Heating Load               768 non-null    float64
#  9   Cooling Load               768 non-null    float64
# dtypes: float64(10)
# memory usage: 60.1 KB

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# All the features were retained because each feature represents an important physical characteristic of a building that directly influences its heating load. The dataset contains only eight predictor variables, and they were specifically designed for building energy efficiency analysis. Removing any feature could lead to the loss of valuable information and reduce the model's predictive performance. Therefore, all features were used to ensure that the regression models learned from the complete set of relevant building characteristics.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Dimensionality reduction was not performed because the dataset contains only eight predictor variables, all of which are meaningful building design parameters. Since the number of features is already small and each feature has a direct relationship with the target variable (Heating Load), reducing the dimensionality could result in the loss of useful information and make the model less interpretable. Therefore, all original features were retained.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split

X = df.drop('Heating Load', axis=1)
y = df['Heating Load']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42
)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)


X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# I used an 80:20 train-test split, where 80% of the data was used for training the regression models and 20% was reserved for testing their performance on unseen data.
#
# **Enough data for training**
#
# The dataset contains 768 samples.
# Using 80% provides about 614 samples for training, allowing the models to learn the relationships between building characteristics and heating load effectively.
#
# **Reliable model evaluation**
#
# The remaining 20% (about 154 samples) is used to evaluate how well the model performs on unseen data, giving a realistic estimate of its predictive ability.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train_scaled, y_train)

lr_pred = lr.predict(X_test_scaled)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("Linear Regression Performance")
print("MAE :", mean_absolute_error(y_test, lr_pred))
print("MSE :", mean_squared_error(y_test, lr_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, lr_pred)))
print("R² Score :", r2_score(y_test, lr_pred))
# Out:
# Linear Regression Performance
# MAE : 1.37956958477514
# MSE : 3.7819398523091974
# RMSE: 1.9447210217173048
# R² Score : 0.9637159779243152

# %%
# Visualizing evaluation Metric Score chart
import matplotlib.pyplot as plt
import numpy as np

mae = mean_absolute_error(y_test, lr_pred)
mse = mean_squared_error(y_test, lr_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, lr_pred)

metrics = ['MAE', 'MSE', 'RMSE', 'R²']
values = [mae, mse, rmse, r2]

plt.figure(figsize=(7,5))
plt.bar(metrics, values)

plt.title("Linear Regression Evaluation Metrics")
plt.ylabel("Metric Value")

for i, value in enumerate(values):
    plt.text(i, value, round(value,3), ha='center', va='bottom')

plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

cv_scores = cross_val_score(
    lr,
    X_train_scaled,
    y_train,
    cv=5,
    scoring='r2'
)

print("Cross Validation Scores:", cv_scores)
print("Average R²:", cv_scores.mean())
# Out:
# Cross Validation Scores: [0.96736606 0.97153699 0.96805715 0.96735422 0.9727138 ]
# Average R²: 0.9694056415557704

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Linear Regression has no important hyperparameters to tune. Once the model is fitted, there are no regularization parameters like alpha.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, there is a small improvement, but it's important to explain what actually improved.

# %%
import matplotlib.pyplot as plt

# R² Scores
labels = ['Before CV', 'After 5-Fold CV']
r2_scores = [0.9637, 0.9694]

plt.figure(figsize=(6,5))
bars = plt.bar(labels, r2_scores)

plt.title('Linear Regression Performance Improvement')
plt.ylabel('R² Score')
plt.ylim(0.94, 1.00)

# Add values on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 0.001,
        f'{height:.4f}',
        ha='center',
        fontsize=10
    )

plt.show()

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)

ridge.fit(X_train_scaled, y_train)

ridge_pred = ridge.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("Ridge Regression Performance")

print("MAE :", mean_absolute_error(y_test, ridge_pred))
print("MSE :", mean_squared_error(y_test, ridge_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, ridge_pred)))
print("R² Score :", r2_score(y_test, ridge_pred))
# Out:
# Ridge Regression Performance
# MAE : 1.377145182185529
# MSE : 3.78645164970225
# RMSE: 1.945880687427225
# R² Score : 0.9636726916314065

# %%
# Visualizing evaluation Metric Score chart
import matplotlib.pyplot as plt
import numpy as np

mae = mean_absolute_error(y_test, ridge_pred)
mse = mean_squared_error(y_test, ridge_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, ridge_pred)

metrics = ['MAE','MSE','RMSE','R²']
values = [mae,mse,rmse,r2]

plt.figure(figsize=(7,5))
bars = plt.bar(metrics, values)

plt.title("Ridge Regression Evaluation Metrics")
plt.ylabel("Metric Value")

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2,
             height,
             f'{height:.3f}',
             ha='center',
             va='bottom')

plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(
    ridge,
    X_train_scaled,
    y_train,
    cv=5,
    scoring='r2'
)

print("Cross Validation Scores:", cv_scores)
print("Average R²:", cv_scores.mean())
# Out:
# Cross Validation Scores: [0.96731556 0.97156244 0.96802367 0.9673831  0.97283789]
# Average R²: 0.9694245333781704

# %%
from sklearn.linear_model import RidgeCV

alphas = [0.001,0.01,0.1,1,10,100]

ridge_cv = RidgeCV(alphas=alphas, cv=5)

ridge_cv.fit(X_train_scaled, y_train)

print("Best Alpha:", ridge_cv.alpha_)
# Out:
# Best Alpha: 1.0

# %%
best_ridge = Ridge(alpha=ridge_cv.alpha_)

best_ridge.fit(X_train_scaled, y_train)

ridge_cv_pred = best_ridge.predict(X_test_scaled)

# %%
print("After Hyperparameter Tuning")

print("MAE :", mean_absolute_error(y_test, ridge_cv_pred))
print("MSE :", mean_squared_error(y_test, ridge_cv_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, ridge_cv_pred)))
print("R² :", r2_score(y_test, ridge_cv_pred))
# Out:
# After Hyperparameter Tuning
# MAE : 1.377145182185529
# MSE : 3.78645164970225
# RMSE: 1.945880687427225
# R² : 0.9636726916314065

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Ridge Regression has a regularization parameter called alpha, which controls the strength of the penalty. Hyperparameter tuning was performed using RidgeCV to automatically identify the alpha value that provides the best predictive performance.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Hyperparameter tuning using RidgeCV produced almost the same performance as the original Ridge Regression model. While the MAE decreased slightly, the changes in MSE, RMSE, and R² were negligible. This indicates that the default Ridge model was already close to the optimal solution for the Energy Efficiency dataset.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Ridge Regression provides highly accurate predictions of building heating load, enabling engineers and architects to design more energy-efficient buildings. Accurate predictions reduce unnecessary energy consumption, lower HVAC installation and operating costs, minimize design errors, and improve project planning. With an R² score of over 96%, the model is reliable enough to support informed decision-making during the building design process, leading to cost savings and more sustainable construction practices.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)

lasso.fit(X_train_scaled, y_train)

lasso_pred = lasso.predict(X_test_scaled)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("Lasso Regression Performance")

print("MAE :", mean_absolute_error(y_test, lasso_pred))
print("MSE :", mean_squared_error(y_test, lasso_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, lasso_pred)))
print("R² :", r2_score(y_test, lasso_pred))
# Out:
# Lasso Regression Performance
# MAE : 1.3999155516528057
# MSE : 3.847054235617644
# RMSE: 1.9613908931209108
# R² : 0.9630912689618061

# %%
import matplotlib.pyplot as plt

mae = mean_absolute_error(y_test, lasso_pred)
mse = mean_squared_error(y_test, lasso_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, lasso_pred)

metrics = ['MAE','MSE','RMSE','R²']
values = [mae,mse,rmse,r2]

plt.figure(figsize=(7,5))
bars = plt.bar(metrics, values)

plt.title("Lasso Regression Evaluation Metrics")
plt.ylabel("Metric Value")

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2,
             height,
             f'{height:.3f}',
             ha='center',
             va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm


# Predict on the model
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(
    lasso,
    X_train_scaled,
    y_train,
    cv=5,
    scoring='r2'
)

print("Cross Validation Scores:", cv_scores)
print("Average R²:", cv_scores.mean())
# Out:
# Cross Validation Scores: [0.96800508 0.97111208 0.96686559 0.96644092 0.97349844]
# Average R²: 0.9691844214840664

# %%
from sklearn.linear_model import LassoCV

lasso_cv = LassoCV(
    alphas=[0.001,0.01,0.1,1,10,100],
    cv=5,
    random_state=42
)

lasso_cv.fit(X_train_scaled, y_train)

print("Best Alpha:", lasso_cv.alpha_)
# Out:
# Best Alpha: 0.001

# %%
best_lasso = Lasso(alpha=lasso_cv.alpha_)

best_lasso.fit(X_train_scaled, y_train)

lasso_cv_pred = best_lasso.predict(X_test_scaled)

# %%
print("After Hyperparameter Tuning")

print("MAE :", mean_absolute_error(y_test, lasso_cv_pred))
print("MSE :", mean_squared_error(y_test, lasso_cv_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, lasso_cv_pred)))
print("R² :", r2_score(y_test, lasso_cv_pred))
# Out:
# After Hyperparameter Tuning
# MAE : 1.381290788636035
# MSE : 3.7860245028780333
# RMSE: 1.945770927647454
# R² : 0.9636767896883308

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used LassoCV for hyperparameter optimization. LassoCV automatically evaluates multiple values of the regularization parameter (alpha) using 5-fold cross-validation and selects the value that gives the best model performance. This approach eliminates manual trial-and-error, improves model reliability, and helps find the optimal balance between prediction accuracy and model complexity.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Interpretation
#
# MAE decreased, meaning the average prediction error became smaller.
#
# MSE decreased, indicating fewer large prediction errors.
#
# RMSE decreased, showing that the average prediction error was reduced.
#
# R² increased slightly, meaning the tuned model explains a little more of the variation in Heating Load than before.
#
# Although the improvements are modest, they consistently move in the desired direction, showing that hyperparameter tuning produced a slightly better model.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# For your Energy Efficiency (Heating Load Prediction) project, the evaluation metrics that have the most positive business impact are MAE, RMSE, and R² Score. While MSE is useful for model development, it is less intuitive from a business perspective.
#
# 1. MAE (Mean Absolute Error)
#
# Why was it considered?
#
# MAE measures the average difference between the predicted and actual heating load. Since it is expressed in the same unit as the target variable, it is easy for engineers, architects, and business stakeholders to understand.
#
# 2. RMSE (Root Mean Squared Error)
#
# Why was it considered?
#
# RMSE measures the average prediction error while giving more importance to large errors. It is also expressed in the same units as Heating Load.
#
# 3. R² Score
#
# Why was it considered?
#
# R² measures how well the model explains the variation in Heating Load.
#
# Your model achieved approximately 96%, meaning it explains almost all the variation in energy demand.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Based on thr results, the best final prediction model is Ridge Regression.
# Why?
#
# Best overall performance
#
# Ridge Regression achieved the lowest MAE (1.3771) among all three models, meaning it had the smallest average prediction error.
#
# Stable predictions
#
# Its RMSE and R² Score were almost identical to Linear Regression, showing consistently accurate predictions.
#
# Handles multicollinearity
#
# Some predictor variables in the Energy Efficiency dataset, such as Surface Area, Wall Area, and Roof Area, are related to one another.
#
# Ridge Regression uses L2 regularization to reduce the effect of multicollinearity by shrinking coefficient values while retaining all important features.
#
# No feature loss
#
# Unlike Lasso Regression, Ridge Regression does not remove features by setting coefficients to zero.
#
# Since all eight building characteristics are important for predicting heating load, retaining all features is beneficial.
#
# Good generalization
#
# The average 5-fold Cross-Validation R² of approximately 0.9694 indicates that Ridge Regression performs consistently well on different subsets of the data and generalizes well to unseen data.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Since your final model is Ridge Regression, a good explainability tool is SHAP(SHapley Additive exPlanations).
#
# **Explain the model**
#
# Ridge Regression
#
# Ridge Regression is a linear regression model that uses L2 Regularization to reduce overfitting and handle multicollinearity. It adds a penalty term to the loss function, shrinking the regression coefficients without eliminating any feature. This helps improve the model's stability and generalization while retaining all important building characteristics.

# %%
import shap

explainer = shap.Explainer(best_ridge, X_train_scaled)

shap_values = explainer(X_test_scaled)
# Out:
# WARNING:shap:Background dataset has 614 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=614 when initializing the masker.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
